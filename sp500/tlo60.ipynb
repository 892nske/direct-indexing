# %%
import os as os
import numpy as np
import scipy.stats as st
import cvxpy as cvx
import pandas as pd
import datetime
import warnings
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
warnings.filterwarnings('ignore')

# %%
# 二回目の銘柄数
constCnt = 60

portName = 'portfolio'+str(constCnt)


#過去指数ファンド情報読み取り
tickers=pd.read_csv('sp500_alive.csv')
tickers=tickers['ticker'].to_list()     #ticker列のデータ取得

#一件目のファンドの過去日付データ読み取り
data = pd.read_csv('./data/'+tickers[0]+'.csv')
data = data.drop(['Open', 'High','Low','Close','Adj Close','Volume'], axis=1)

dataDate = data.copy()

# %%
#過去期間2013-01-02～2018-12-31のファンドの過去データ取得
for ticker in tickers:
    d = pd.read_csv('./data/'+ticker+'.csv')
    d = d.drop(['Open', 'High','Low','Adj Close','Volume'], axis=1)
    d = d.rename(columns={'Close': ticker}) #列名称をファンド名にリネーム
    
    date1 = d.iat[0,0]
    if date1 == "2012-12-31":
        data = pd.merge(data,d,on='Date')

# %%
data=data[data['Date'] != "2012-12-31"]
data.reset_index(inplace=True, drop=True)

# %%
data.head()
# Out:
#          Date       AAPL       MSFT     AMZN    NVDA      GOOGL       GOOG  \
# 0  2013-01-02  19.608213  27.620001  12.8655  3.1800  18.099348  18.013729
# 1  2013-01-03  19.360714  27.250000  12.9240  3.1825  18.109859  18.024191
# 2  2013-01-04  18.821428  26.740000  12.9575  3.2875  18.467718  18.380356
# 3  2013-01-07  18.710714  26.690001  13.4230  3.1925  18.387136  18.300158
# 4  2013-01-08  18.761070  26.549999  13.3190  3.1225  18.350851  18.264042
#
#         META        UNH      TSLA  ...        DVA        ALK        DXC  \
# 0  28.000000  54.540001  2.357333  ...  54.599998  21.969999  20.617765
# 1  27.770000  51.990002  2.318000  ...  54.965000  22.379999  20.652542
# 2  28.760000  52.090000  2.293333  ...  54.919998  22.690001  20.697256
# 3  29.420000  52.090000  2.289333  ...  54.145000  23.174999  20.478659
# 4  29.059999  51.400002  2.245333  ...  54.834999  23.000000  20.061335
#
#          MHK          RL        CMA       ZION        NWL        LNC  \
# 0  93.169998  152.100006  31.320000  21.990000  22.610001  27.410000
# 1  93.269997  157.210007  31.719999  22.020000  22.459999  27.900000
# 2  93.519997  159.389999  32.590000  22.650000  22.549999  28.110001
# 3  92.739998  161.520004  32.340000  22.540001  22.139999  27.799999
# 4  93.300003  162.250000  31.930000  22.090000  22.209999  27.370001
#
#         DISH
# 0  36.959999
# 1  36.930000
# 2  36.889999
# 3  36.340000
# 4  35.970001
#
# [5 rows x 460 columns]

# %%
#日付、年、月、週というデータを取得する
cal = data[['Date']]
cal['Datetime'] = pd.to_datetime(cal['Date'])
cal['year'] = cal['Datetime'].dt.year
cal['month'] = cal['Datetime'].dt.month
cal['week'] = cal['Datetime'].dt.week

cal['mon'] = 1
for index, row in cal.iterrows():
    if index > 0 and cal.iloc[index,3] != cal.iloc[index-1,3]:
        cal.iloc[index,5] = cal.iloc[index-1,5]+1
    else:
        cal.iloc[index,5] = cal.iloc[index-1,5]
        
cal['iweek'] = 1
for index, row in cal.iterrows():
    if index > 0 and cal.iloc[index,4] != cal.iloc[index-1,4]:
        cal.iloc[index,6] = cal.iloc[index-1,6]+1
    else:
        cal.iloc[index,6] = cal.iloc[index-1,6]

# %%
#インデックス設定
data = data.set_index('Date')

# 行・列の差分・変化率を取得する
R = data.pct_change()
R = R.fillna(0)

#累積しないリターンを保存
Rd = R
R = R + 1

#累積リータン
R = R.cumprod()

#配列T：縦、N：横
T = Rd.shape[0]
N = Rd.shape[1]

#ベンチマーク情報
Benchmark = pd.read_csv('sp500.csv')
Benchmark = Benchmark.set_index('Date')
Benchmark = Benchmark.drop(['Open', 'High','Low','Adj Close','Volume'], axis=1)

# %%
#------------------------------------------------
#シミュレーション
#------------------------------------------------
di = Benchmark.copy() # ポートフォリオの時価総額の推移
Benchmarkd = Benchmark.copy()
Benchmarkd = Benchmarkd.pct_change()
Benchmarkd = Benchmarkd.fillna(0)

did = Benchmark.copy() #日次
did100 = Benchmark.copy() #日次


#最適ウェイト計算の
mon_window = 48 # 6年間72月


w_init = np.ones(N)/N
w_initd = np.ones(N)/N
# w_initm = np.ones(N)/N

N100=constCnt
w_init100 = np.ones(N100)/N100
w_initd100 = np.ones(N100)/N100



for i in range(120 - mon_window):
    start = 1
    end = i+mon_window
    
    # 計算対象の開始終了
    startdate = cal.query('mon >= '+str(start)+' and mon <= '+str(end))['Date'].min()
    enddate = cal.query('mon >= '+str(start)+' and mon <= '+str(end))['Date'].max()

    # 日次リターンで最適化
    # 各資産の計算期間分のデータを取得し計算期間初からのリターンを計算
    assetd = Rd[startdate:enddate]
    assetd = assetd.values
    
    # ベンチマークの計算期間分のデータを取得し計算期間初からのリターンを計算
    indxd = Benchmarkd[startdate:enddate]
    indxd = indxd.values
    indxd = np.squeeze(indxd)

    # 最適化ソルバでウェイトを算出
    weightd = cvx.Variable(N,value=w_initd)
    objd = cvx.Minimize(cvx.sum_squares((assetd@weightd) - indxd))
    mintracerrd = cvx.Problem(objd, [cvx.sum(weightd) == 1.0,weightd >= 0])
    mintracerrd.solve(verbose=False)
    wd = weightd.value
    
    wd[wd<0]=0
    wd=wd/wd.sum()
    w_initd = wd
    
    #--------------------------------------------------------------------
    # ウェイト上位100のファンドを判断し、再最適化ツルバでウェイトを算出
    wdSorted = sorted(wd, reverse=True)
    max100 = []
    for j in range(constCnt):
        weightValue = wdSorted[j]
        max100 = max100 + [m for m, v in enumerate(wd) if v == weightValue]
            
    tickers100 = []
    tickersList = R.columns
    for n in range(constCnt):
        indexN = max100[n]
        tickers100.append(tickersList[indexN])
    
    print(tickers100)
    
    Rd100 = Rd.copy()
    R100 = R.copy()
    for m in range(len(tickersList)):
        colName = tickersList[m]
        n = 0
        for j in range(constCnt):
            if colName == tickers100[j]:
                n = 1
        if(n==0):   
            Rd100 = Rd100.drop(colName,axis=1)
            R100 = R100.drop(colName,axis=1)

    assetd100 = Rd100[startdate:enddate]    
    assetd100 = assetd100.values
    
    weightd100 = cvx.Variable(N100,value=w_initd100)
    objd100 = cvx.Minimize(cvx.sum_squares((assetd100@weightd100) - indxd))
    mintracerrd100 = cvx.Problem(objd100, [cvx.sum(weightd100) == 1.0,weightd100 >= 0])
    mintracerrd100.solve(verbose=False)
    wd100 = weightd100.value
    
    wd100[wd100<0]=0
    wd100=wd100/wd100.sum()
    w_initd100 = wd100
    
    #----------------------------------------------------------------------
    
    # 計算したウェイトと運用期間の各資産のリターンから運用期間のポートフォリオの時価評価額の比率を計算
    dstart = cal.query('mon >= '+str(end+1)+' and mon <= '+str(end+1))['Date'].min()
    dend = cal.query('mon >= '+str(end+1)+' and mon <= '+str(end+1))['Date'].max()
    dstartm1 = cal.query('mon >= '+str(end)+' and mon <= '+str(end))['Date'].max()

    #Backtest期間
    rtmpd=R[dstartm1:dend]
        
    rtmpd = rtmpd.pct_change()
    rtmpd = rtmpd.dropna()
    rtmpd = rtmpd + 1
    rtmpd = rtmpd.cumprod()

    dd = rtmpd.values@wd
    dd = dd*did.at[dstartm1,'Close']

    dd = np.expand_dims(dd, 1)
    did[dstart:dend]=dd
    
    #--------------------------------------------------------------------
    rtmpd100=R100[dstartm1:dend]
    rtmpd100 = rtmpd100.pct_change()
    rtmpd100 = rtmpd100.dropna()
    rtmpd100 = rtmpd100 + 1
    rtmpd100 = rtmpd100.cumprod()
    dd100 = rtmpd100.values@wd100
    dd100 = dd100*did100.at[dstartm1,'Close']
    dd100 = np.expand_dims(dd100, 1)
    did100[dstart:dend]=dd100
    #----------------------------------------------------------------------
# Out:
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'GE', 'PFE', 'JPM', 'GOOGL', 'KO', 'T', 'CVX', 'DIS', 'IBM', 'BAC', 'INTC', 'UNH', 'PM', 'CMCSA', 'MDT', 'SLB', 'MRK', 'AMZN', 'PG', 'AMGN', 'BMY', 'MO', 'GILD', 'HD', 'CSCO', 'GOOG', 'VZ', 'C', 'ORCL', 'QCOM', 'AXP', 'MMM', 'WMT', 'AIG', 'PEP', 'GS', 'MA', 'ACN', 'UNP', 'ADP', 'SO', 'EMR', 'DD', 'WBA', 'LNT', 'F', 'NKE', 'V', 'CVS', 'L', 'SPG', 'LMT', 'YUM', 'EOG', 'LLY']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'PFE', 'GE', 'JPM', 'T', 'KO', 'CVX', 'GOOGL', 'IBM', 'DIS', 'BAC', 'INTC', 'CMCSA', 'UNH', 'PM', 'MDT', 'AMZN', 'MRK', 'PG', 'SLB', 'AMGN', 'MO', 'BMY', 'GILD', 'HD', 'GOOG', 'CSCO', 'ORCL', 'PEP', 'GS', 'MMM', 'WMT', 'AXP', 'C', 'MA', 'AIG', 'VZ', 'QCOM', 'DD', 'ADP', 'ACN', 'WBA', 'NKE', 'UNP', 'EMR', 'LMT', 'V', 'L', 'SO', 'YUM', 'CVS', 'F', 'BKNG', 'EOG', 'LLY', 'PARA']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'GE', 'PFE', 'JPM', 'CVX', 'KO', 'T', 'IBM', 'DIS', 'GOOGL', 'BAC', 'INTC', 'CMCSA', 'UNH', 'PM', 'MDT', 'AMZN', 'MRK', 'PG', 'GOOG', 'SLB', 'AMGN', 'MO', 'HD', 'BMY', 'GILD', 'CSCO', 'GS', 'PEP', 'MMM', 'ORCL', 'C', 'WMT', 'AXP', 'AIG', 'VZ', 'QCOM', 'MA', 'DD', 'NKE', 'LMT', 'ACN', 'SPG', 'WBA', 'UNP', 'EMR', 'L', 'V', 'YUM', 'EOG', 'SO', 'PNC', 'BIIB', 'CVS', 'EFX', 'LLY']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'GE', 'JPM', 'PFE', 'T', 'KO', 'GOOGL', 'CVX', 'IBM', 'DIS', 'BAC', 'PM', 'CMCSA', 'INTC', 'PG', 'UNH', 'AMZN', 'MRK', 'MDT', 'AMGN', 'SLB', 'MO', 'BMY', 'GILD', 'HD', 'GOOG', 'CSCO', 'AXP', 'ORCL', 'C', 'PEP', 'WMT', 'MMM', 'GS', 'QCOM', 'AIG', 'DD', 'MA', 'VZ', 'NKE', 'LMT', 'PNC', 'WBA', 'UNP', 'SPG', 'V', 'EMR', 'ACN', 'EOG', 'CAT', 'EFX', 'YUM', 'L', 'F', 'PARA', 'ADP']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'GE', 'JPM', 'PFE', 'T', 'GOOGL', 'KO', 'CVX', 'BAC', 'IBM', 'DIS', 'PM', 'INTC', 'PG', 'CMCSA', 'UNH', 'AMZN', 'MRK', 'MDT', 'AMGN', 'SLB', 'MO', 'HD', 'BMY', 'GILD', 'CSCO', 'GOOG', 'AXP', 'ORCL', 'C', 'PEP', 'GS', 'MMM', 'WMT', 'QCOM', 'DD', 'PNC', 'AIG', 'MA', 'NKE', 'LMT', 'WBA', 'V', 'VZ', 'UNP', 'EMR', 'EOG', 'EFX', 'SPG', 'CAT', 'ACN', 'F', 'L', 'YUM', 'PARA', 'ADP']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'GE', 'PFE', 'T', 'JPM', 'CVX', 'KO', 'GOOGL', 'IBM', 'BAC', 'PM', 'DIS', 'PG', 'INTC', 'CMCSA', 'AMZN', 'MRK', 'MDT', 'UNH', 'AMGN', 'MO', 'SLB', 'HD', 'BMY', 'GILD', 'ORCL', 'GOOG', 'PEP', 'C', 'AXP', 'GS', 'PNC', 'MMM', 'CSCO', 'WMT', 'DD', 'QCOM', 'MA', 'LMT', 'NKE', 'VZ', 'V', 'L', 'AIG', 'EOG', 'WBA', 'SPG', 'UNP', 'ADP', 'ACN', 'CAT', 'MCD', 'HON', 'BIIB', 'CVS', 'META']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'T', 'JPM', 'PFE', 'CVX', 'KO', 'GE', 'GOOGL', 'PM', 'BAC', 'CMCSA', 'PG', 'IBM', 'DIS', 'AMZN', 'INTC', 'MRK', 'UNH', 'SLB', 'HD', 'AMGN', 'GOOG', 'MO', 'MDT', 'PNC', 'BMY', 'GILD', 'ORCL', 'C', 'AXP', 'CSCO', 'MMM', 'GS', 'WMT', 'PEP', 'DD', 'MA', 'UNP', 'V', 'EOG', 'LMT', 'MCD', 'QCOM', 'AIG', 'VZ', 'WBA', 'MDLZ', 'NKE', 'HON', 'ACN', 'BAX', 'L', 'YUM', 'BIIB', 'COST', 'F']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'T', 'GOOGL', 'JPM', 'PFE', 'CVX', 'KO', 'GE', 'PM', 'CMCSA', 'BAC', 'PG', 'AMZN', 'DIS', 'IBM', 'INTC', 'SLB', 'MRK', 'HD', 'UNH', 'AMGN', 'MO', 'ORCL', 'MMM', 'PEP', 'MDT', 'GOOG', 'GILD', 'BMY', 'WMT', 'CSCO', 'PNC', 'DD', 'AXP', 'C', 'V', 'UNP', 'MCD', 'EOG', 'GS', 'MA', 'AIG', 'LMT', 'HON', 'QCOM', 'ACN', 'WBA', 'NKE', 'VZ', 'MDLZ', 'BAX', 'F', 'BIIB', 'META', 'YUM', 'CAT']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'GOOGL', 'T', 'PFE', 'JPM', 'GE', 'CVX', 'KO', 'PM', 'BAC', 'CMCSA', 'PG', 'AMZN', 'INTC', 'IBM', 'DIS', 'SLB', 'AMGN', 'UNH', 'MRK', 'HD', 'MO', 'ORCL', 'PEP', 'GILD', 'PNC', 'BMY', 'MDT', 'WMT', 'CSCO', 'MMM', 'AXP', 'GS', 'DD', 'V', 'C', 'EOG', 'UNP', 'GOOG', 'MA', 'MCD', 'LMT', 'HON', 'AIG', 'QCOM', 'WBA', 'ACN', 'SO', 'NKE', 'VZ', 'MDLZ', 'BIIB', 'META', 'YUM', 'ADP', 'BA']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'GOOGL', 'JNJ', 'T', 'PFE', 'JPM', 'CVX', 'PM', 'GE', 'BAC', 'KO', 'CMCSA', 'AMZN', 'IBM', 'PG', 'INTC', 'SLB', 'DIS', 'AMGN', 'UNH', 'MRK', 'MO', 'HD', 'PEP', 'MDT', 'ORCL', 'BMY', 'GILD', 'CSCO', 'GS', 'PNC', 'WMT', 'MCD', 'MMM', 'C', 'AXP', 'DD', 'MA', 'V', 'HON', 'EOG', 'UNP', 'LMT', 'QCOM', 'AIG', 'GOOG', 'VZ', 'WBA', 'ACN', 'ADP', 'MDLZ', 'META', 'YUM', 'NKE', 'BA', 'RTX', 'SO']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'T', 'PFE', 'GOOGL', 'JPM', 'PM', 'KO', 'BAC', 'AMZN', 'CMCSA', 'CVX', 'GE', 'PG', 'INTC', 'IBM', 'SLB', 'AMGN', 'UNH', 'DIS', 'HD', 'PEP', 'MO', 'MDT', 'MRK', 'MCD', 'BMY', 'GS', 'GOOG', 'ORCL', 'CSCO', 'GILD', 'PNC', 'C', 'AXP', 'MA', 'MMM', 'WMT', 'HON', 'EOG', 'V', 'DD', 'LMT', 'UNP', 'QCOM', 'WBA', 'AIG', 'MDLZ', 'META', 'YUM', 'LLY', 'ACN', 'BIIB', 'VZ', 'BA', 'RTX', 'L']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'PFE', 'T', 'GOOGL', 'PM', 'JPM', 'KO', 'CVX', 'BAC', 'AMZN', 'CMCSA', 'INTC', 'GE', 'PG', 'IBM', 'SLB', 'HD', 'UNH', 'AMGN', 'DIS', 'MCD', 'GOOG', 'GS', 'MDT', 'MA', 'PEP', 'MO', 'CSCO', 'MRK', 'BMY', 'WMT', 'ORCL', 'GILD', 'AXP', 'HON', 'MMM', 'PNC', 'C', 'EOG', 'LMT', 'UNP', 'SO', 'V', 'DD', 'WBA', 'LLY', 'ACN', 'YUM', 'L', 'AIG', 'MDLZ', 'META', 'QCOM', 'BA', 'VZ', 'RTX']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'PFE', 'T', 'GOOGL', 'PM', 'JPM', 'KO', 'AMZN', 'CVX', 'GE', 'BAC', 'INTC', 'PG', 'IBM', 'CMCSA', 'SLB', 'UNH', 'HD', 'DIS', 'AMGN', 'MCD', 'GS', 'MA', 'GOOG', 'MDT', 'MO', 'PEP', 'WMT', 'MRK', 'BMY', 'CSCO', 'ORCL', 'GILD', 'MMM', 'AXP', 'HON', 'C', 'PNC', 'LMT', 'EOG', 'DD', 'V', 'UNP', 'SO', 'YUM', 'WBA', 'MDLZ', 'AIG', 'LLY', 'ACN', 'META', 'QCOM', 'L', 'RTX', 'VZ', 'BA']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'GOOGL', 'JNJ', 'PFE', 'T', 'KO', 'PM', 'AMZN', 'JPM', 'BAC', 'GE', 'CVX', 'CMCSA', 'SLB', 'IBM', 'INTC', 'PG', 'UNH', 'AMGN', 'DIS', 'HD', 'MCD', 'PEP', 'MA', 'GS', 'MDT', 'CSCO', 'MRK', 'MO', 'ORCL', 'WMT', 'BMY', 'MMM', 'GILD', 'HON', 'EOG', 'C', 'LMT', 'PNC', 'AXP', 'GOOG', 'DD', 'V', 'RTX', 'WBA', 'L', 'BA', 'YUM', 'UNP', 'VZ', 'MDLZ', 'META', 'ACN', 'QCOM', 'BIIB', 'AIG', 'SO']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'PFE', 'JNJ', 'GOOGL', 'T', 'JPM', 'KO', 'AMZN', 'CVX', 'BAC', 'GE', 'PM', 'IBM', 'INTC', 'CMCSA', 'SLB', 'HD', 'UNH', 'PG', 'AMGN', 'DIS', 'MCD', 'MO', 'CSCO', 'MA', 'GS', 'MDT', 'AXP', 'ORCL', 'PNC', 'GILD', 'HON', 'MMM', 'EOG', 'GOOG', 'LMT', 'BMY', 'MRK', 'V', 'DD', 'PEP', 'UNP', 'WBA', 'BA', 'MDLZ', 'WMT', 'C', 'YUM', 'QCOM', 'SO', 'META', 'VZ', 'LLY', 'CAT', 'ACN', 'RTX', 'MAR']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'PFE', 'T', 'JPM', 'CVX', 'GOOGL', 'BAC', 'AMZN', 'KO', 'IBM', 'INTC', 'PM', 'GOOG', 'CMCSA', 'SLB', 'AMGN', 'GE', 'UNH', 'HD', 'DIS', 'PG', 'MCD', 'CSCO', 'GS', 'MDT', 'MA', 'HON', 'PNC', 'MMM', 'GILD', 'ORCL', 'EOG', 'AXP', 'DD', 'BMY', 'LMT', 'V', 'MO', 'MDLZ', 'WMT', 'BA', 'MRK', 'ACN', 'PEP', 'QCOM', 'YUM', 'COST', 'WBA', 'UNP', 'MAR', 'L', 'ADP', 'META', 'C', 'VZ', 'LLY']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'PFE', 'CVX', 'JPM', 'AMZN', 'KO', 'GOOGL', 'BAC', 'INTC', 'T', 'IBM', 'GOOG', 'GE', 'SLB', 'PM', 'UNH', 'AMGN', 'HD', 'CMCSA', 'DIS', 'CSCO', 'MMM', 'MA', 'PG', 'MDT', 'GS', 'PNC', 'GILD', 'LMT', 'HON', 'DD', 'EOG', 'ORCL', 'AXP', 'MCD', 'ACN', 'V', 'VZ', 'MDLZ', 'BA', 'WMT', 'MO', 'BMY', 'MRK', 'PEP', 'COST', 'QCOM', 'SO', 'L', 'YUM', 'META', 'MAR', 'CAT', 'WBA', 'C', 'ADP']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'PFE', 'GOOGL', 'CVX', 'JPM', 'AMZN', 'KO', 'INTC', 'BAC', 'T', 'GE', 'IBM', 'PM', 'SLB', 'CMCSA', 'UNH', 'HD', 'AMGN', 'CSCO', 'DIS', 'MMM', 'MDT', 'GOOG', 'GS', 'MA', 'PG', 'PNC', 'GILD', 'HON', 'ACN', 'ORCL', 'LMT', 'AXP', 'EOG', 'V', 'DD', 'MCD', 'MDLZ', 'BMY', 'BA', 'VZ', 'MO', 'MRK', 'COST', 'EMR', 'WMT', 'SO', 'L', 'QCOM', 'C', 'META', 'CAT', 'WBA', 'MAR', 'ADP', 'VFC']
# ['AAPL', 'XOM', 'MSFT', 'JNJ', 'WFC', 'PFE', 'GOOGL', 'JPM', 'CVX', 'AMZN', 'KO', 'BAC', 'INTC', 'T', 'GE', 'IBM', 'CMCSA', 'SLB', 'PM', 'UNH', 'HD', 'CSCO', 'AMGN', 'GOOG', 'DIS', 'MMM', 'MA', 'MDT', 'GS', 'ACN', 'GILD', 'PG', 'V', 'LMT', 'DD', 'EOG', 'BA', 'PNC', 'MCD', 'HON', 'BMY', 'MDLZ', 'MRK', 'MO', 'VZ', 'EMR', 'AXP', 'SO', 'ORCL', 'ABT', 'MAR', 'CAT', 'UNP', 'QCOM', 'COST', 'L', 'WBA', 'META', 'YUM', 'WMT']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'PFE', 'JPM', 'CVX', 'GOOGL', 'AMZN', 'INTC', 'KO', 'BAC', 'T', 'GE', 'UNH', 'HD', 'MA', 'SLB', 'PM', 'GOOG', 'IBM', 'CSCO', 'CMCSA', 'MDT', 'DIS', 'AMGN', 'MMM', 'LMT', 'PG', 'GS', 'ACN', 'GILD', 'MO', 'HON', 'EOG', 'MCD', 'BA', 'DD', 'PNC', 'VZ', 'META', 'MRK', 'AXP', 'EMR', 'BMY', 'SO', 'UNP', 'V', 'CAT', 'MAR', 'ORCL', 'BAX', 'COST', 'TROW', 'ABT', 'MDLZ', 'WMT', 'F', 'WBA']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'JNJ', 'JPM', 'PFE', 'CVX', 'GOOGL', 'AMZN', 'INTC', 'KO', 'BAC', 'GE', 'T', 'GOOG', 'UNH', 'MA', 'SLB', 'HD', 'IBM', 'CSCO', 'CMCSA', 'PM', 'PG', 'DIS', 'AMGN', 'MDT', 'MMM', 'LMT', 'MO', 'GS', 'GILD', 'ACN', 'MCD', 'EOG', 'HON', 'DD', 'BA', 'VZ', 'META', 'AXP', 'BMY', 'PNC', 'UNP', 'MRK', 'EMR', 'MAR', 'ORCL', 'V', 'TROW', 'PEP', 'BAX', 'CAT', 'ABT', 'C', 'MDLZ', 'COST', 'YUM', 'SO']
# ['AAPL', 'XOM', 'MSFT', 'WFC', 'GOOGL', 'JPM', 'PFE', 'JNJ', 'CVX', 'AMZN', 'INTC', 'KO', 'BAC', 'UNH', 'T', 'GE', 'MA', 'HD', 'SLB', 'DIS', 'IBM', 'CSCO', 'PM', 'CMCSA', 'PG', 'AMGN', 'MDT', 'LMT', 'MMM', 'ACN', 'GS', 'EOG', 'MCD', 'GILD', 'MO', 'BA', 'DD', 'VZ', 'META', 'PNC', 'AXP', 'EMR', 'HON', 'BMY', 'UNP', 'MRK', 'ABT', 'TROW', 'GOOG', 'V', 'ORCL', 'MAR', 'BAX', 'PEP', 'COST', 'MDLZ', 'SPG', 'CAT', 'YUM', 'C']
# ['AAPL', 'MSFT', 'XOM', 'WFC', 'GOOGL', 'PFE', 'JPM', 'CVX', 'JNJ', 'AMZN', 'T', 'INTC', 'KO', 'BAC', 'MA', 'UNH', 'SLB', 'IBM', 'HD', 'GE', 'CSCO', 'DIS', 'PG', 'CMCSA', 'GS', 'PM', 'LMT', 'AMGN', 'ACN', 'MDT', 'BA', 'EOG', 'HON', 'GILD', 'ADP', 'MMM', 'DD', 'AXP', 'UNP', 'TROW', 'EMR', 'V', 'ABT', 'META', 'PEP', 'COST', 'MO', 'MCD', 'MAR', 'MRK', 'GOOG', 'BMY', 'VZ', 'SPG', 'ORCL', 'MDLZ', 'ADBE', 'L', 'WMT', 'C']
# ['AAPL', 'XOM', 'MSFT', 'GOOGL', 'WFC', 'PFE', 'JPM', 'CVX', 'AMZN', 'JNJ', 'T', 'KO', 'MA', 'INTC', 'BAC', 'UNH', 'HD', 'IBM', 'SLB', 'CSCO', 'DIS', 'GE', 'PG', 'GS', 'CMCSA', 'AMGN', 'ACN', 'LMT', 'MDT', 'PM', 'ADP', 'MMM', 'BA', 'GILD', 'DD', 'AXP', 'UNP', 'TROW', 'META', 'PEP', 'EOG', 'MO', 'ABT', 'MRK', 'BMY', 'HON', 'V', 'COST', 'EMR', 'VZ', 'MCD', 'SPG', 'CAT', 'CVS', 'L', 'PGR', 'ORCL', 'MAR', 'ADBE', 'C']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'WFC', 'PFE', 'JPM', 'CVX', 'AMZN', 'JNJ', 'T', 'KO', 'MA', 'INTC', 'BAC', 'UNH', 'HD', 'IBM', 'DIS', 'CSCO', 'PG', 'GS', 'SLB', 'GE', 'AMGN', 'CMCSA', 'LMT', 'MMM', 'ADP', 'PM', 'MDT', 'ACN', 'BA', 'GILD', 'AXP', 'DD', 'UNP', 'ABT', 'META', 'PEP', 'TROW', 'EOG', 'BMY', 'MRK', 'COST', 'V', 'MO', 'VZ', 'SPG', 'CVS', 'CAT', 'EMR', 'HON', 'L', 'MCD', 'INTU', 'ADBE', 'C', 'ORCL', 'MAR']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'WFC', 'PFE', 'JPM', 'CVX', 'AMZN', 'JNJ', 'KO', 'INTC', 'UNH', 'T', 'MA', 'BAC', 'IBM', 'HD', 'DIS', 'CSCO', 'SLB', 'PG', 'GE', 'AMGN', 'CMCSA', 'GS', 'ADP', 'LMT', 'BA', 'ABT', 'VZ', 'MDT', 'ACN', 'DD', 'PM', 'UNP', 'MMM', 'GILD', 'PEP', 'BMY', 'AXP', 'META', 'MRK', 'V', 'TROW', 'C', 'COST', 'CAT', 'L', 'EMR', 'MAR', 'EOG', 'HON', 'MO', 'CVS', 'ADBE', 'SPG', 'INTU', 'MCD', 'PNC']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'WFC', 'PFE', 'AMZN', 'JPM', 'CVX', 'JNJ', 'UNH', 'INTC', 'T', 'MA', 'KO', 'HD', 'IBM', 'BAC', 'DIS', 'CSCO', 'SLB', 'PG', 'AMGN', 'GE', 'CMCSA', 'GS', 'ADP', 'LMT', 'ABT', 'MDT', 'BA', 'PEP', 'DD', 'PM', 'ACN', 'UNP', 'VZ', 'MMM', 'GILD', 'AXP', 'C', 'BMY', 'META', 'TROW', 'MRK', 'COST', 'CAT', 'V', 'EOG', 'SPG', 'MCD', 'CVS', 'ADBE', 'EMR', 'PNC', 'PGR', 'HON', 'MO', 'MAR', 'INTU']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'WFC', 'PFE', 'CVX', 'JPM', 'AMZN', 'JNJ', 'UNH', 'MA', 'KO', 'INTC', 'T', 'HD', 'IBM', 'BAC', 'DIS', 'CSCO', 'SLB', 'PG', 'AMGN', 'CMCSA', 'ADP', 'GS', 'MDT', 'LMT', 'GE', 'BA', 'ABT', 'VZ', 'DD', 'UNP', 'PEP', 'PM', 'AXP', 'ACN', 'GILD', 'META', 'BMY', 'MMM', 'C', 'MRK', 'TROW', 'CAT', 'COST', 'CVS', 'SPG', 'MCD', 'V', 'EOG', 'MO', 'PNC', 'ADBE', 'PGR', 'EMR', 'MAR', 'MDLZ', 'INTU']
# ['AAPL', 'GOOGL', 'MSFT', 'XOM', 'JPM', 'PFE', 'WFC', 'AMZN', 'JNJ', 'CVX', 'DIS', 'UNH', 'KO', 'MA', 'INTC', 'HD', 'T', 'BAC', 'CSCO', 'IBM', 'SLB', 'PG', 'AMGN', 'GS', 'ADP', 'CMCSA', 'LMT', 'ABT', 'GE', 'BA', 'MDT', 'VZ', 'PM', 'UNP', 'DD', 'AXP', 'PEP', 'GILD', 'META', 'ACN', 'TROW', 'MRK', 'BMY', 'PNC', 'SPG', 'EOG', 'MCD', 'CAT', 'CVS', 'C', 'COST', 'EMR', 'V', 'ADBE', 'MDLZ', 'PGR', 'HON', 'L', 'MMM', 'MAR']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'JPM', 'PFE', 'WFC', 'JNJ', 'AMZN', 'CVX', 'KO', 'DIS', 'HD', 'UNH', 'MA', 'INTC', 'T', 'CSCO', 'BAC', 'IBM', 'PG', 'SLB', 'AMGN', 'GS', 'ADP', 'CMCSA', 'BA', 'LMT', 'GE', 'ABT', 'MDT', 'UNP', 'AXP', 'DD', 'VZ', 'PM', 'META', 'PEP', 'ACN', 'MRK', 'BMY', 'GILD', 'TROW', 'EOG', 'CVS', 'MCD', 'C', 'PNC', 'SPG', 'CAT', 'COST', 'ADBE', 'EMR', 'V', 'HON', 'MDLZ', 'WMT', 'PGR', 'MMM', 'WEC']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'JPM', 'PFE', 'JNJ', 'WFC', 'AMZN', 'CVX', 'UNH', 'MA', 'DIS', 'HD', 'T', 'KO', 'INTC', 'CSCO', 'BAC', 'PG', 'ADP', 'IBM', 'SLB', 'GS', 'CMCSA', 'BA', 'ABT', 'AMGN', 'MDT', 'GE', 'UNP', 'AXP', 'META', 'PEP', 'TROW', 'LMT', 'ACN', 'MRK', 'GILD', 'CAT', 'VZ', 'PM', 'BMY', 'EMR', 'EOG', 'MCD', 'PNC', 'SPG', 'CVS', 'C', 'ADBE', 'COST', 'WMT', 'V', 'MDLZ', 'LLY', 'HON', 'PGR', 'MAR', 'MMM']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'JNJ', 'WFC', 'AMZN', 'CVX', 'UNH', 'MA', 'DIS', 'HD', 'T', 'INTC', 'KO', 'PG', 'BAC', 'CSCO', 'GS', 'SLB', 'CMCSA', 'IBM', 'BA', 'ADP', 'MDT', 'ABT', 'AXP', 'PEP', 'LMT', 'GE', 'META', 'ACN', 'AMGN', 'TROW', 'UNP', 'GILD', 'MRK', 'VZ', 'EMR', 'CAT', 'BMY', 'PNC', 'MCD', 'EOG', 'GOOG', 'ADBE', 'C', 'PM', 'COST', 'SPG', 'CVS', 'WMT', 'V', 'MDLZ', 'PGR', 'PSX', 'LLY', 'RTX']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'JNJ', 'AMZN', 'WFC', 'CVX', 'UNH', 'MA', 'DIS', 'T', 'KO', 'HD', 'INTC', 'PG', 'BAC', 'GS', 'CSCO', 'CMCSA', 'BA', 'IBM', 'SLB', 'ADP', 'PEP', 'MDT', 'AXP', 'LMT', 'ABT', 'ACN', 'META', 'AMGN', 'TROW', 'MRK', 'GILD', 'VZ', 'UNP', 'GE', 'EMR', 'CAT', 'WMT', 'BMY', 'EOG', 'MCD', 'ADBE', 'COST', 'GOOG', 'CVS', 'PNC', 'C', 'PM', 'PSX', 'V', 'PGR', 'WEC', 'MDLZ', 'LLY', 'RTX']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'JNJ', 'AMZN', 'CVX', 'MA', 'WFC', 'UNH', 'DIS', 'T', 'KO', 'INTC', 'HD', 'PG', 'BAC', 'GS', 'CMCSA', 'CSCO', 'AXP', 'BA', 'ADP', 'IBM', 'ACN', 'SLB', 'MRK', 'AMGN', 'PEP', 'LMT', 'MDT', 'META', 'ABT', 'VZ', 'WEC', 'UNP', 'TROW', 'GILD', 'GE', 'GOOG', 'BMY', 'WMT', 'CVS', 'MCD', 'COST', 'EMR', 'ADBE', 'EOG', 'CAT', 'C', 'PM', 'BAX', 'MAR', 'RTX', 'LLY', 'DHR', 'PSX', 'MDLZ']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'JNJ', 'AMZN', 'MA', 'CVX', 'UNH', 'WFC', 'DIS', 'T', 'KO', 'HD', 'INTC', 'BAC', 'GS', 'PG', 'CMCSA', 'CSCO', 'ACN', 'AXP', 'BA', 'IBM', 'MRK', 'ADP', 'AMGN', 'MDT', 'SLB', 'LMT', 'META', 'PEP', 'ABT', 'WEC', 'TROW', 'GILD', 'MCD', 'GOOG', 'GE', 'UNP', 'VZ', 'EMR', 'CVS', 'BMY', 'COST', 'WMT', 'EOG', 'PM', 'ADBE', 'C', 'CAT', 'RTX', 'PNC', 'LLY', 'MAR', 'TRV', 'PSX', 'DHR']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'AMZN', 'JNJ', 'CVX', 'MA', 'WFC', 'DIS', 'UNH', 'T', 'HD', 'KO', 'INTC', 'BAC', 'PG', 'GS', 'CMCSA', 'ACN', 'CSCO', 'MRK', 'IBM', 'BA', 'AXP', 'ADP', 'AMGN', 'GOOG', 'MDT', 'LMT', 'META', 'TROW', 'PEP', 'ABT', 'SLB', 'GILD', 'MCD', 'GE', 'WEC', 'UNP', 'VZ', 'EMR', 'WMT', 'CVS', 'COST', 'BMY', 'PM', 'EOG', 'ADBE', 'CAT', 'C', 'PSX', 'LLY', 'RTX', 'PNC', 'MAR', 'TRV', 'BAX']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'AMZN', 'JNJ', 'CVX', 'MA', 'DIS', 'WFC', 'UNH', 'T', 'HD', 'KO', 'INTC', 'PG', 'BAC', 'GS', 'CMCSA', 'ACN', 'CSCO', 'MRK', 'AXP', 'IBM', 'BA', 'ADP', 'AMGN', 'MDT', 'META', 'GOOG', 'ABT', 'LMT', 'SLB', 'TROW', 'GILD', 'WEC', 'PEP', 'MCD', 'UNP', 'GE', 'VZ', 'PM', 'WMT', 'EMR', 'CVS', 'BMY', 'C', 'COST', 'ADBE', 'CAT', 'EOG', 'PSX', 'TRV', 'RTX', 'LLY', 'PNC', 'MAR', 'MDLZ']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'JNJ', 'AMZN', 'CVX', 'MA', 'WFC', 'DIS', 'UNH', 'HD', 'T', 'KO', 'INTC', 'BAC', 'PG', 'GS', 'IBM', 'CMCSA', 'ACN', 'AXP', 'MRK', 'CSCO', 'TROW', 'MDT', 'BA', 'LMT', 'AMGN', 'META', 'ADP', 'ABT', 'GE', 'GILD', 'VZ', 'MCD', 'GOOG', 'UNP', 'EMR', 'PEP', 'PM', 'SLB', 'WEC', 'COST', 'WMT', 'CVS', 'BMY', 'ADBE', 'CAT', 'EOG', 'RTX', 'C', 'LLY', 'PNC', 'BAX', 'MAR', 'TRV', 'MDLZ']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'JPM', 'PFE', 'AMZN', 'JNJ', 'CVX', 'DIS', 'MA', 'WFC', 'UNH', 'HD', 'T', 'KO', 'INTC', 'PG', 'BAC', 'MRK', 'GS', 'CSCO', 'BA', 'CMCSA', 'IBM', 'MDT', 'TROW', 'ACN', 'WEC', 'UNP', 'META', 'AXP', 'GILD', 'SLB', 'GE', 'VZ', 'PM', 'LMT', 'AMGN', 'ABT', 'ADP', 'GOOG', 'MCD', 'COST', 'WMT', 'BMY', 'PEP', 'CVS', 'EOG', 'ADBE', 'EMR', 'CAT', 'V', 'MAR', 'MS', 'C', 'RTX', 'BAX', 'LLY', 'INTU']
# ['AAPL', 'MSFT', 'XOM', 'GOOGL', 'PFE', 'AMZN', 'JPM', 'JNJ', 'HD', 'KO', 'UNH', 'MA', 'WFC', 'DIS', 'PG', 'T', 'BAC', 'INTC', 'CVX', 'MRK', 'CMCSA', 'VZ', 'CSCO', 'META', 'WMT', 'TROW', 'GOOG', 'ED', 'IBM', 'UNP', 'COST', 'GILD', 'LMT', 'GS', 'ADP', 'ACN', 'PM', 'CAT', 'EOG', 'ABT', 'TRV', 'LIN', 'CVS', 'GE', 'AMGN', 'BAX', 'BMY', 'ADBE', 'MS', 'SLB', 'MAR', 'DHR', 'MDT', 'V', 'TMO', 'PEP', 'PSX', 'AXP', 'ORCL', 'MMC']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'JNJ', 'AMZN', 'HD', 'PFE', 'UNH', 'JPM', 'PG', 'INTC', 'WFC', 'T', 'ABT', 'MMC', 'CVX', 'MRK', 'KO', 'DIS', 'CMCSA', 'VZ', 'BAC', 'ADP', 'META', 'MS', 'UNP', 'WMT', 'MA', 'CSCO', 'ADBE', 'COST', 'GS', 'CAT', 'IBM', 'CVS', 'DHR', 'LMT', 'MDLZ', 'BAX', 'BMY', 'LIN', 'MCD', 'GOOG', 'ACN', 'AMGN', 'SLB', 'ED', 'GILD', 'GE', 'V', 'BK', 'ANSS', 'PM', 'QCOM', 'TMO', 'PEP', 'LLY', 'NKE', 'TROW']
# ['AAPL', 'MSFT', 'GOOGL', 'XOM', 'JNJ', 'PFE', 'AMZN', 'HD', 'JPM', 'UNH', 'INTC', 'MMC', 'T', 'CVX', 'ABT', 'MRK', 'VZ', 'KO', 'UNP', 'PG', 'DIS', 'CMCSA', 'WFC', 'BAC', 'ADBE', 'META', 'WMT', 'MS', 'COST', 'CSCO', 'ADP', 'BLK', 'MA', 'GS', 'CVS', 'IBM', 'DHR', 'BMY', 'BAX', 'MCD', 'AMGN', 'PEP', 'MDLZ', 'LIN', 'CAT', 'BK', 'V', 'EOG', 'ACN', 'TMO', 'CL', 'QCOM', 'ANSS', 'GILD', 'LLY', 'GE', 'PM', 'LMT', 'TROW', 'GOOG']
# ['AAPL', 'MSFT', 'GOOGL', 'JNJ', 'XOM', 'AMZN', 'PFE', 'JPM', 'UNH', 'HD', 'INTC', 'MMC', 'T', 'CVX', 'DIS', 'ABT', 'VZ', 'MRK', 'KO', 'PG', 'UNP', 'CMCSA', 'GS', 'WMT', 'META', 'ADBE', 'BLK', 'BAC', 'MS', 'WFC', 'COST', 'MA', 'CSCO', 'PEP', 'DHR', 'LIN', 'AMGN', 'CVS', 'BMY', 'ADP', 'MCD', 'IBM', 'BAX', 'BK', 'MDLZ', 'CL', 'V', 'ACN', 'EOG', 'LMT', 'CAT', 'TMO', 'GILD', 'ARE', 'LLY', 'TROW', 'ANSS', 'QCOM', 'NKE', 'SNPS']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'XOM', 'JNJ', 'PFE', 'UNH', 'T', 'DIS', 'HD', 'JPM', 'MMC', 'BAC', 'GS', 'MRK', 'INTC', 'PG', 'UNP', 'MA', 'CVX', 'META', 'CMCSA', 'VZ', 'ABT', 'ADBE', 'KO', 'COST', 'WMT', 'AMGN', 'CSCO', 'UPS', 'PEP', 'MCD', 'LIN', 'BLK', 'DHR', 'IBM', 'CVS', 'MS', 'BMY', 'EOG', 'WFC', 'TROW', 'ACN', 'TMO', 'BAX', 'LLY', 'ARE', 'QCOM', 'BK', 'SLB', 'TECH', 'MDLZ', 'CME', 'MET', 'FE', 'SNPS', 'ADP', 'BA']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'XOM', 'PFE', 'UNH', 'T', 'DIS', 'HD', 'MMC', 'ADBE', 'GS', 'MRK', 'INTC', 'CVX', 'JPM', 'BAC', 'META', 'CMCSA', 'VZ', 'PG', 'COST', 'AMGN', 'KO', 'UNP', 'ABT', 'MCD', 'LIN', 'PEP', 'MA', 'WMT', 'DHR', 'SNPS', 'ACN', 'UPS', 'CSCO', 'EOG', 'BLK', 'IBM', 'BMY', 'MS', 'TROW', 'GOOG', 'WFC', 'CVS', 'QCOM', 'MDLZ', 'TMO', 'LLY', 'CME', 'CRM', 'BAX', 'ARE', 'FE', 'PNC', 'LMT', 'WEC', 'BA']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'PFE', 'JNJ', 'XOM', 'UNH', 'T', 'DIS', 'CVX', 'ADBE', 'HD', 'JPM', 'GS', 'CMCSA', 'MMC', 'WMT', 'META', 'MRK', 'VZ', 'AMGN', 'BAC', 'UNP', 'INTC', 'COST', 'PG', 'SNPS', 'KO', 'LIN', 'ABT', 'UPS', 'PEP', 'IBM', 'BLK', 'DHR', 'EOG', 'MA', 'BMY', 'TMO', 'TROW', 'MS', 'MCD', 'QCOM', 'NEE', 'WEC', 'ACN', 'WFC', 'CSCO', 'ANSS', 'MDLZ', 'ORCL', 'CRM', 'BA', 'LMT', 'GOOG', 'LLY', 'CVS', 'CME', 'TECH']
# ['AAPL', 'MSFT', 'AMZN', 'JNJ', 'GOOGL', 'PFE', 'XOM', 'UNH', 'DIS', 'T', 'ADBE', 'CMCSA', 'CVX', 'VZ', 'HD', 'GS', 'WMT', 'JPM', 'META', 'PEP', 'AMGN', 'PG', 'UNP', 'MRK', 'SNPS', 'UPS', 'BAC', 'GOOG', 'COST', 'MMC', 'LIN', 'KO', 'ABT', 'INTC', 'EOG', 'DHR', 'ACN', 'BLK', 'QCOM', 'MA', 'WFC', 'ANSS', 'BMY', 'IBM', 'NEE', 'MDLZ', 'TMO', 'MCD', 'TROW', 'BA', 'C', 'MS', 'ORCL', 'LMT', 'CRM', 'INTU', 'ARE', 'EL', 'CSCO', 'CME']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'PFE', 'XOM', 'DIS', 'T', 'HD', 'ADBE', 'VZ', 'PG', 'CMCSA', 'SNPS', 'JPM', 'GS', 'META', 'UNP', 'MRK', 'CVX', 'WMT', 'COST', 'BAC', 'UPS', 'AMGN', 'LIN', 'PEP', 'ABT', 'DHR', 'TMO', 'INTC', 'WFC', 'QCOM', 'EOG', 'KO', 'ACN', 'BLK', 'MMC', 'BMY', 'LMT', 'MA', 'TROW', 'MCD', 'NEE', 'IBM', 'GOOG', 'MDLZ', 'BIIB', 'C', 'ANSS', 'EL', 'INTU', 'ORCL', 'CRM', 'BA', 'PLD', 'FE', 'LLY']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'PFE', 'XOM', 'PG', 'VZ', 'HD', 'CMCSA', 'DIS', 'ADBE', 'JPM', 'T', 'SNPS', 'GS', 'META', 'UNP', 'CVX', 'MRK', 'WMT', 'BAC', 'COST', 'LIN', 'ABT', 'TMO', 'AMGN', 'UPS', 'PEP', 'INTC', 'DHR', 'BLK', 'MMC', 'QCOM', 'EOG', 'WFC', 'ACN', 'KO', 'MCD', 'MA', 'BMY', 'LMT', 'IBM', 'EL', 'TROW', 'MDLZ', 'BIIB', 'NEE', 'C', 'ANSS', 'ORCL', 'INTU', 'GOOG', 'BA', 'XEL', 'CRM', 'PLD', 'CSCO']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'PFE', 'XOM', 'CMCSA', 'JPM', 'ADBE', 'HD', 'T', 'DIS', 'SNPS', 'META', 'VZ', 'CVX', 'PG', 'COST', 'UNP', 'KO', 'WMT', 'ABT', 'AMGN', 'BAC', 'LIN', 'GS', 'MRK', 'TMO', 'BLK', 'INTC', 'UPS', 'EOG', 'MCD', 'MA', 'QCOM', 'PEP', 'WFC', 'ACN', 'TROW', 'EL', 'MMC', 'ORCL', 'ANSS', 'XEL', 'PLD', 'BMY', 'ARE', 'IBM', 'BA', 'DHR', 'MDLZ', 'LMT', 'NEE', 'BIIB', 'INTU', 'DOV', 'C', 'CRM']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'PFE', 'CMCSA', 'XOM', 'JPM', 'ADBE', 'SNPS', 'T', 'HD', 'DIS', 'CVX', 'META', 'PG', 'VZ', 'KO', 'UNP', 'COST', 'AMGN', 'WMT', 'LIN', 'INTC', 'BLK', 'TMO', 'GS', 'BAC', 'PEP', 'ABT', 'UPS', 'MRK', 'ANSS', 'MA', 'QCOM', 'ACN', 'EOG', 'MCD', 'TROW', 'WFC', 'EL', 'XEL', 'DHR', 'BMY', 'BA', 'NEE', 'PLD', 'INTU', 'IBM', 'ORCL', 'MDLZ', 'LMT', 'ARE', 'BIIB', 'C', 'DOV', 'TXN', 'CSCO']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'PFE', 'JPM', 'CMCSA', 'XOM', 'ADBE', 'SNPS', 'CVX', 'T', 'DIS', 'HD', 'META', 'PG', 'COST', 'VZ', 'WMT', 'KO', 'UNP', 'LIN', 'GS', 'BLK', 'INTC', 'NEE', 'AMGN', 'TMO', 'ABT', 'PEP', 'MRK', 'ANSS', 'MCD', 'UPS', 'QCOM', 'MA', 'ACN', 'INTU', 'EOG', 'BAC', 'EL', 'TROW', 'WFC', 'BMY', 'BA', 'DHR', 'PLD', 'IBM', 'ICE', 'C', 'ARE', 'MDLZ', 'BIIB', 'MMC', 'LMT', 'DOV', 'PCAR', 'FAST']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'PFE', 'UNH', 'JPM', 'CMCSA', 'XOM', 'SNPS', 'ADBE', 'HD', 'CVX', 'DIS', 'T', 'META', 'PG', 'COST', 'VZ', 'UNP', 'WMT', 'LIN', 'BLK', 'KO', 'TMO', 'INTC', 'AMGN', 'NEE', 'ABT', 'PEP', 'GS', 'ANSS', 'MRK', 'QCOM', 'MCD', 'INTU', 'UPS', 'MA', 'EOG', 'ACN', 'BAC', 'TROW', 'EL', 'DHR', 'BA', 'BMY', 'PCAR', 'ICE', 'PLD', 'WFC', 'IBM', 'ARE', 'LMT', 'BIIB', 'ORCL', 'MDLZ', 'C', 'LLY', 'FAST']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'PFE', 'CMCSA', 'SNPS', 'XOM', 'ADBE', 'HD', 'CVX', 'COST', 'META', 'T', 'DIS', 'PG', 'VZ', 'UNP', 'WMT', 'BLK', 'NEE', 'TMO', 'KO', 'LIN', 'INTC', 'ABT', 'AMGN', 'PEP', 'QCOM', 'GS', 'ANSS', 'MRK', 'EL', 'MA', 'MCD', 'ACN', 'INTU', 'DHR', 'EOG', 'BAC', 'UPS', 'ICE', 'BA', 'PCAR', 'BMY', 'ARE', 'CB', 'WFC', 'LMT', 'MET', 'TROW', 'PLD', 'IBM', 'BIIB', 'ORCL', 'DOV', 'MDLZ']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'JPM', 'UNH', 'PFE', 'SNPS', 'XOM', 'CMCSA', 'ADBE', 'HD', 'CVX', 'T', 'COST', 'META', 'DIS', 'PG', 'NEE', 'VZ', 'UNP', 'LIN', 'TMO', 'WMT', 'BLK', 'KO', 'INTC', 'AMGN', 'PEP', 'QCOM', 'ABT', 'GS', 'ANSS', 'MRK', 'DHR', 'EL', 'MCD', 'MA', 'ACN', 'INTU', 'ICE', 'EOG', 'BAC', 'UPS', 'BA', 'PCAR', 'BMY', 'TROW', 'WFC', 'LMT', 'CB', 'ARE', 'MET', 'IBM', 'ORCL', 'BIIB', 'PLD', 'MDLZ', 'DOV']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'JPM', 'PFE', 'UNH', 'XOM', 'SNPS', 'CMCSA', 'CVX', 'ADBE', 'T', 'HD', 'META', 'DIS', 'COST', 'NEE', 'VZ', 'UNP', 'WMT', 'BLK', 'KO', 'TMO', 'LIN', 'PG', 'INTC', 'GS', 'PEP', 'AMGN', 'QCOM', 'ABT', 'ANSS', 'MRK', 'MA', 'EL', 'MCD', 'DHR', 'ACN', 'INTU', 'ICE', 'EOG', 'UPS', 'BA', 'BAC', 'PCAR', 'TROW', 'BMY', 'CB', 'WFC', 'PLD', 'MET', 'ARE', 'BIIB', 'ORCL', 'LMT', 'MDLZ', 'IBM', 'DOV']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'JPM', 'PFE', 'UNH', 'XOM', 'CMCSA', 'SNPS', 'ADBE', 'CVX', 'HD', 'T', 'DIS', 'META', 'COST', 'VZ', 'BLK', 'NEE', 'UNP', 'KO', 'PG', 'WMT', 'LIN', 'TMO', 'INTC', 'PEP', 'QCOM', 'ABT', 'GS', 'AMGN', 'ANSS', 'EL', 'MCD', 'MRK', 'MA', 'ACN', 'INTU', 'ICE', 'DHR', 'EOG', 'BA', 'UPS', 'BAC', 'TROW', 'BMY', 'PCAR', 'CB', 'PLD', 'ARE', 'ORCL', 'DOV', 'IBM', 'LMT', 'BIIB', 'LLY', 'MET', 'MDLZ']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JPM', 'JNJ', 'PFE', 'UNH', 'XOM', 'CMCSA', 'SNPS', 'CVX', 'DIS', 'ADBE', 'META', 'COST', 'HD', 'T', 'VZ', 'LIN', 'NEE', 'PG', 'UNP', 'KO', 'WMT', 'BLK', 'TMO', 'GS', 'INTC', 'QCOM', 'PEP', 'ABT', 'ANSS', 'EL', 'AMGN', 'ACN', 'MCD', 'INTU', 'MA', 'MRK', 'DHR', 'BAC', 'ICE', 'TROW', 'EOG', 'BA', 'BMY', 'UPS', 'PCAR', 'CB', 'ARE', 'LMT', 'DOV', 'BIIB', 'PLD', 'WFC', 'IBM', 'TECH', 'ORCL', 'LLY']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'JPM', 'PFE', 'UNH', 'XOM', 'SNPS', 'CMCSA', 'COST', 'HD', 'DIS', 'CVX', 'META', 'ADBE', 'T', 'VZ', 'LIN', 'NEE', 'KO', 'PG', 'TMO', 'UNP', 'WMT', 'GS', 'BLK', 'INTC', 'PEP', 'QCOM', 'MCD', 'ABT', 'ANSS', 'EL', 'INTU', 'MA', 'AMGN', 'ACN', 'ICE', 'DHR', 'BAC', 'MRK', 'EOG', 'TROW', 'BA', 'WFC', 'BMY', 'UPS', 'PLD', 'PCAR', 'DOV', 'ARE', 'LMT', 'LLY', 'BIIB', 'CB', 'MDLZ', 'TECH', 'ORCL']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'JPM', 'UNH', 'PFE', 'XOM', 'HD', 'DIS', 'SNPS', 'COST', 'ADBE', 'CVX', 'META', 'CMCSA', 'LIN', 'NEE', 'VZ', 'T', 'KO', 'PG', 'TMO', 'UNP', 'WMT', 'INTC', 'GS', 'BLK', 'PEP', 'QCOM', 'MCD', 'INTU', 'ANSS', 'ABT', 'EL', 'ACN', 'AMGN', 'TROW', 'ICE', 'MRK', 'MA', 'BAC', 'WFC', 'DHR', 'BA', 'ARE', 'EOG', 'DOV', 'BMY', 'LMT', 'PLD', 'UPS', 'LLY', 'IBM', 'NVDA', 'TECH', 'PCAR', 'ORCL', 'BIIB']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'JPM', 'UNH', 'ADBE', 'XOM', 'COST', 'DIS', 'HD', 'PFE', 'CVX', 'LIN', 'SNPS', 'NEE', 'META', 'VZ', 'CMCSA', 'T', 'KO', 'PG', 'TROW', 'INTC', 'PEP', 'QCOM', 'MCD', 'WMT', 'UNP', 'GS', 'BLK', 'TMO', 'INTU', 'EL', 'AMGN', 'MRK', 'ANSS', 'ARE', 'ABT', 'ICE', 'LLY', 'WFC', 'BA', 'DHR', 'UPS', 'NVDA', 'BAC', 'ORCL', 'ACN', 'IBM', 'LMT', 'PCAR', 'TECH', 'EOG', 'IDXX', 'DOV', 'MA', 'BIIB', 'BMY']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'COST', 'ADBE', 'DIS', 'XOM', 'PFE', 'HD', 'SNPS', 'VZ', 'META', 'CVX', 'NEE', 'LIN', 'CMCSA', 'KO', 'PEP', 'T', 'GS', 'INTC', 'TROW', 'PG', 'BLK', 'QCOM', 'MCD', 'EL', 'TMO', 'WMT', 'INTU', 'ARE', 'AMGN', 'WFC', 'UNP', 'MRK', 'DHR', 'ANSS', 'ABT', 'ICE', 'LLY', 'BA', 'NVDA', 'TECH', 'ORCL', 'UPS', 'ACN', 'LMT', 'DOV', 'EOG', 'IBM', 'IDXX', 'PCAR', 'BIIB', 'MA', 'BMY', 'V']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'COST', 'DIS', 'ADBE', 'XOM', 'SNPS', 'PFE', 'NEE', 'HD', 'META', 'CMCSA', 'VZ', 'CVX', 'LIN', 'KO', 'PG', 'QCOM', 'T', 'TROW', 'MCD', 'EL', 'GS', 'INTC', 'BLK', 'PEP', 'ARE', 'WFC', 'AMGN', 'MRK', 'INTU', 'TMO', 'UNP', 'WMT', 'ANSS', 'LLY', 'ABT', 'DHR', 'ACN', 'ICE', 'NVDA', 'ORCL', 'DOV', 'BA', 'EOG', 'TECH', 'PCAR', 'UPS', 'IBM', 'DD', 'BIIB', 'BMY', 'LMT', 'V', 'IDXX']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'COST', 'DIS', 'ADBE', 'SNPS', 'PFE', 'LIN', 'META', 'XOM', 'CMCSA', 'NEE', 'PG', 'HD', 'VZ', 'CVX', 'KO', 'WFC', 'T', 'QCOM', 'TROW', 'MCD', 'EL', 'PEP', 'INTC', 'BLK', 'INTU', 'MRK', 'TMO', 'ARE', 'GS', 'AMGN', 'UNP', 'WMT', 'LLY', 'ABT', 'DHR', 'ANSS', 'ORCL', 'NVDA', 'DOV', 'ACN', 'ICE', 'BA', 'PCAR', 'EOG', 'BAC', 'TECH', 'DD', 'UPS', 'V', 'BMY', 'BIIB', 'IBM', 'IDXX']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'DIS', 'COST', 'ADBE', 'SNPS', 'PFE', 'XOM', 'LIN', 'META', 'CMCSA', 'VZ', 'HD', 'TROW', 'KO', 'NEE', 'QCOM', 'CVX', 'PG', 'EL', 'T', 'WFC', 'MCD', 'INTC', 'BLK', 'TMO', 'INTU', 'PEP', 'MRK', 'ARE', 'GS', 'AMGN', 'UNP', 'ABT', 'WMT', 'ANSS', 'DHR', 'ACN', 'LLY', 'ORCL', 'NVDA', 'PCAR', 'ICE', 'DOV', 'BA', 'V', 'BAC', 'DD', 'EOG', 'TECH', 'UPS', 'BIIB', 'BMY', 'PNC', 'IDXX']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'DIS', 'COST', 'ADBE', 'XOM', 'META', 'PFE', 'SNPS', 'LIN', 'CMCSA', 'NEE', 'TROW', 'VZ', 'QCOM', 'HD', 'PG', 'CVX', 'WFC', 'KO', 'PEP', 'INTU', 'EL', 'BLK', 'T', 'TMO', 'MCD', 'INTC', 'MRK', 'ARE', 'ABT', 'AMGN', 'UNP', 'GS', 'DHR', 'ANSS', 'ACN', 'NVDA', 'ORCL', 'LLY', 'WMT', 'BAC', 'BA', 'V', 'PCAR', 'ICE', 'EOG', 'DD', 'DOV', 'TECH', 'UPS', 'BMY', 'BIIB', 'PNC', 'MMC']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'DIS', 'COST', 'ADBE', 'XOM', 'META', 'CMCSA', 'PFE', 'SNPS', 'LIN', 'TROW', 'NEE', 'VZ', 'QCOM', 'PG', 'CVX', 'PEP', 'WFC', 'HD', 'INTU', 'T', 'EL', 'KO', 'MCD', 'TMO', 'INTC', 'BLK', 'MRK', 'ABT', 'ARE', 'ACN', 'AMGN', 'DHR', 'UNP', 'LLY', 'NVDA', 'ANSS', 'GS', 'BAC', 'PCAR', 'WMT', 'ORCL', 'ICE', 'BA', 'V', 'DOV', 'DD', 'EOG', 'TECH', 'BIIB', 'BMY', 'MMC', 'UPS', 'NKE']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'JPM', 'UNH', 'DIS', 'COST', 'ADBE', 'XOM', 'META', 'PFE', 'NEE', 'TROW', 'SNPS', 'VZ', 'LIN', 'CVX', 'CMCSA', 'PEP', 'QCOM', 'WFC', 'INTU', 'T', 'EL', 'PG', 'HD', 'BLK', 'TMO', 'KO', 'MCD', 'MRK', 'ABT', 'INTC', 'WMT', 'AMGN', 'ACN', 'ARE', 'DHR', 'LLY', 'UNP', 'NVDA', 'ANSS', 'BAC', 'ORCL', 'GS', 'PCAR', 'ICE', 'BA', 'V', 'DD', 'EOG', 'DOV', 'BIIB', 'TECH', 'UPS', 'BMY', 'MMC', 'LMT']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'COST', 'DIS', 'ADBE', 'XOM', 'PFE', 'META', 'NEE', 'LIN', 'CVX', 'TROW', 'VZ', 'CMCSA', 'PEP', 'SNPS', 'QCOM', 'WFC', 'T', 'INTU', 'EL', 'PG', 'TMO', 'BLK', 'HD', 'KO', 'MCD', 'MRK', 'ABT', 'INTC', 'ACN', 'AMGN', 'WMT', 'LLY', 'DHR', 'ANSS', 'NVDA', 'UNP', 'ARE', 'ORCL', 'BAC', 'GS', 'PCAR', 'ICE', 'BA', 'DD', 'V', 'DOV', 'BIIB', 'TECH', 'EOG', 'LMT', 'UPS', 'MMC', 'BMY']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'COST', 'DIS', 'XOM', 'ADBE', 'PFE', 'META', 'LIN', 'NEE', 'CVX', 'CMCSA', 'TROW', 'VZ', 'PEP', 'SNPS', 'QCOM', 'INTU', 'WFC', 'T', 'PG', 'EL', 'TMO', 'BLK', 'KO', 'MCD', 'MRK', 'HD', 'INTC', 'ABT', 'ACN', 'WMT', 'AMGN', 'DHR', 'ANSS', 'NVDA', 'LLY', 'ARE', 'ORCL', 'UNP', 'BAC', 'PCAR', 'GS', 'ICE', 'DD', 'BA', 'LMT', 'V', 'UPS', 'DOV', 'BMY', 'TECH', 'EOG', 'MMC', 'CVS']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'COST', 'JPM', 'DIS', 'XOM', 'ADBE', 'PFE', 'META', 'NEE', 'LIN', 'CMCSA', 'PEP', 'CVX', 'TROW', 'VZ', 'QCOM', 'SNPS', 'INTU', 'PG', 'TMO', 'EL', 'WFC', 'T', 'KO', 'BLK', 'MRK', 'MCD', 'HD', 'INTC', 'ACN', 'ABT', 'AMGN', 'WMT', 'ARE', 'NVDA', 'LLY', 'UNP', 'DHR', 'ANSS', 'PCAR', 'ORCL', 'GS', 'BAC', 'ICE', 'BA', 'UPS', 'DD', 'LMT', 'PNC', 'BMY', 'TECH', 'EOG', 'DOV', 'CVS', 'CRM']
# ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'JNJ', 'UNH', 'JPM', 'DIS', 'COST', 'PEP', 'XOM', 'ADBE', 'PFE', 'LIN', 'META', 'NEE', 'CVX', 'CMCSA', 'INTU', 'QCOM', 'VZ', 'SNPS', 'TMO', 'WFC', 'TROW', 'EL', 'PG', 'MCD', 'T', 'MRK', 'BLK', 'KO', 'INTC', 'ABT', 'ACN', 'WMT', 'LLY', 'HD', 'ARE', 'AMGN', 'NVDA', 'ANSS', 'ORCL', 'UNP', 'PCAR', 'DHR', 'GS', 'ICE', 'BAC', 'BA', 'LMT', 'UPS', 'BMY', 'CRM', 'DOV', 'DD', 'V', 'TECH', 'CVS', 'PNC']

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
ganpon=100000
fig = make_subplots(rows=2, cols=1)


Benchmark.to_csv('b2.csv')
di.to_csv('d2.csv')

from matplotlib import dates as mdates

heights = [4, 1,1,1]
fig = plt.figure(figsize=(20, 20))
spec = fig.add_gridspec(ncols=1, nrows=4,  height_ratios=heights)
#spec = fig.add_gridspec(ncols=1, nrows=5)
ax = fig.add_subplot(spec[0, 0])

#ベンチマーク
ax.plot(pd.to_datetime(Benchmark.index),Benchmark['Close'],c='k')
#フル460銘柄
ax.plot(pd.to_datetime(did.index),did['Close'],c='b',linestyle="-")
#一部銘柄
ax.plot(pd.to_datetime(did100.index),did100['Close'],c='r',linestyle="-")


# ax.legend(labels=['Benchmark S&P500','portfolio460',portName,'portfolio100日次R','portfolio月次R'],fontsize=30)

ax.legend(labels=['Benchmark S&P500','portfolio460',portName],fontsize=30)
ax.set_xlabel('date', size=15)
ax.set_ylabel('value', size=15)
ax.set_title('Benchmark vs. Replication Portfolio', fontsize=30)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(rotation=30)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y/%m'))

#
#TE計算
#

portDaily = did.pct_change()
portDaily = portDaily.fillna(0)

portDaily100 = did100.pct_change()
portDaily100 = portDaily100.fillna(0)

ax = fig.add_subplot(spec[1, 0])
ax.plot(pd.to_datetime(Benchmark.index),((Benchmarkd['Close']-portDaily['Close'])**2)**0.5, c='b')
ax.legend(labels=['portfolio460'],fontsize=20)

ax.set_xlabel('date', size=15)
ax.set_ylabel('tracking error', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(rotation=30)

ax = fig.add_subplot(spec[2, 0])
ax.plot(pd.to_datetime(Benchmark.index),((Benchmarkd['Close']-portDaily100['Close'])**2)**0.5, c='r')
ax.legend(labels=[portName],fontsize=20)

ax.set_xlabel('date', size=15)
ax.set_ylabel('tracking error', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(rotation=30)

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y/%m'))

fig.savefig(portName+'.png')

# %%
did100.to_csv(portName+'.csv')

# %%
te=((Benchmarkd['Close']-portDaily100['Close'])**2)**0.5
te = te['2017-01-01':]
print(te.median())
# Out:
# 0.0009309758908181975
